# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Call the API key from file api.keys
#api_key = api_key.api_key

# Define the base url to which queries shall be made
url = "http://api.openweathermap.org/data/2.5/weather?"

# Specify the units (imperial/metric)
units ="metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed =[]

# Loop through the list of cities and perform a request for data on each
# set the counter at 1
record = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        print(f"Processing Record {record} | {city}")
        print(f"{query_url}+{city}")
        
        record = record + 1
        #to prevent timing out when retrieving the data
        
        time.sleep(0.01)
        
    # if city not found - not all cities are listed.
    except:
        print("City not found. Continue to next city.")
    continue

print(f"-----------------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+cape town
# Processing Record 2 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sorland
# Processing Record 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kodiak
# City not found. Continue to next city.
# Processing Record 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lebu
# Processing Record 5 | djenne
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+djenne
# Processing Record 6 | takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+takoradi
# Processing Record 7 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+luderitz
# Processing Record 8 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ribeira grande
# Processing Record 9 | nicolas bravo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nicolas bravo
# Processing Record 10 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hermanus
# City not found. Continue to next city.
# Processing Record 11 | marivan
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+marivan
# Processing Record 12 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bluff
# Processing Record 13 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+dunedin
# Processing Record 14 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+busselton
# Processing Record 15 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mount pleasant
# Processing Record 16 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ushuaia
# Processing Record 17 | ventspils
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ventspils
# Processing Record 18 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saint-philippe
# Processing Record 19 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+laguna
# Processing Record 20 | gao
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+gao
# Processing Record 21 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+touros
# Processing Record 22 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tuatapere
# Processing Record 23 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+salalah
# Processing Record 24 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vaini
# City not found. Continue to next city.
# Processing Record 25 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+barrow
# Processing Record 26 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port lincoln
# Processing Record 27 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bambous virieux
# City not found. Continue to next city.
# Processing Record 28 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+batagay-alyta
# Processing Record 29 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vao
# Processing Record 30 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+katsuura
# Processing Record 31 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+dingle
# Processing Record 32 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+butaritari
# Processing Record 33 | brigantine
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+brigantine
# Processing Record 34 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bethel
# City not found. Continue to next city.
# Processing Record 35 | sainte-rose
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sainte-rose
# City not found. Continue to next city.
# Processing Record 36 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mahebourg
# Processing Record 37 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mataura
# Processing Record 38 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ilulissat
# City not found. Continue to next city.
# Processing Record 39 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+petropavlovsk-kamchatskiy
# Processing Record 40 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+albany
# Processing Record 41 | arlit
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+arlit
# Processing Record 42 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+atuona
# Processing Record 43 | long beach
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+long beach
# Processing Record 44 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mar del plata
# Processing Record 45 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saldanha
# Processing Record 46 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pevek
# City not found. Continue to next city.
# Processing Record 47 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sao filipe
# Processing Record 48 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+punta arenas
# Processing Record 49 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+maceio
# Processing Record 50 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kavieng
# Processing Record 51 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san patricio
# Processing Record 52 | lewiston
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lewiston
# Processing Record 53 | chipinge
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+chipinge
# Processing Record 54 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+rocha
# Processing Record 55 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hithadhoo
# Processing Record 56 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hobart
# Processing Record 57 | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kenai
# Processing Record 58 | temyasovo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+temyasovo
# Processing Record 59 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hambantota
# Processing Record 60 | penarroya-pueblonuevo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+penarroya-pueblonuevo
# Processing Record 61 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+maniitsoq
# Processing Record 62 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+cockburn town
# Processing Record 63 | khromtau
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+khromtau
# Processing Record 64 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tual
# City not found. Continue to next city.
# Processing Record 65 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+rikitea
# Processing Record 66 | college
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+college
# Processing Record 67 | kurchum
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kurchum
# Processing Record 68 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+esperance
# Processing Record 69 | khasan
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+khasan
# Processing Record 70 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+puerto escondido
# Processing Record 71 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+avarua
# Processing Record 72 | portobelo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+portobelo
# City not found. Continue to next city.
# Processing Record 73 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+iqaluit
# City not found. Continue to next city.
# Processing Record 74 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+castro
# Processing Record 75 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+luwuk
# Processing Record 76 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+upernavik
# Processing Record 77 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+quatre cocos
# Processing Record 78 | nioro
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nioro
# Processing Record 79 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+raudeberg
# Processing Record 80 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+alice springs
# Processing Record 81 | kieta
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kieta
# Processing Record 82 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+arraial do cabo
# Processing Record 83 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nanortalik
# Processing Record 84 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lokosovo
# Processing Record 85 | semnan
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+semnan
# City not found. Continue to next city.
# Processing Record 86 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+cabo san lucas
# Processing Record 87 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kropotkin
# Processing Record 88 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+yellowknife
# Processing Record 89 | along
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+along
# Processing Record 90 | ust-omchug
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ust-omchug
# Processing Record 91 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tuktoyaktuk
# Processing Record 92 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+airai
# Processing Record 93 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bredasdorp
# Processing Record 94 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+severo-kurilsk
# Processing Record 95 | kaduqli
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kaduqli
# Processing Record 96 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+klaksvik
# Processing Record 97 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+praia
# Processing Record 98 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+geraldton
# Processing Record 99 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tiksi
# City not found. Continue to next city.
# Processing Record 100 | sechura
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sechura
# City not found. Continue to next city.
# Processing Record 101 | iralaya
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+iralaya
# Processing Record 102 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mount gambier
# Processing Record 103 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saint george
# City not found. Continue to next city.
# Processing Record 104 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+qaanaaq
# Processing Record 105 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+chapais
# Processing Record 106 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sitka
# Processing Record 107 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sept-iles
# Processing Record 108 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+jamestown
# Processing Record 109 | penzance
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+penzance
# Processing Record 110 | altagracia de orituco
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+altagracia de orituco
# Processing Record 111 | general pico
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+general pico
# Processing Record 112 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+puerto ayora
# Processing Record 113 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vardo
# Processing Record 114 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+stykkisholmur
# Processing Record 115 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+new norfolk
# Processing Record 116 | joshimath
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+joshimath
# Processing Record 117 | lensk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lensk
# Processing Record 118 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+georgetown
# City not found. Continue to next city.
# Processing Record 119 | iguape
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+iguape
# City not found. Continue to next city.
# Processing Record 120 | terney
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+terney
# Processing Record 121 | berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+berlevag
# Processing Record 122 | ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ostersund
# Processing Record 123 | malindi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+malindi
# Processing Record 124 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+provideniya
# Processing Record 125 | semypolky
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+semypolky
# Processing Record 126 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kaitangata
# Processing Record 127 | san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san quintin
# Processing Record 128 | tigil
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tigil
# City not found. Continue to next city.
# Processing Record 129 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pacific grove
# Processing Record 130 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+faanui
# Processing Record 131 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saint-augustin
# Processing Record 132 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+taoudenni
# Processing Record 133 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nantucket
# Processing Record 134 | salta
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+salta
# Processing Record 135 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ponta do sol
# Processing Record 136 | bombay
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bombay
# Processing Record 137 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port blair
# City not found. Continue to next city.
# Processing Record 138 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kapaa
# Processing Record 139 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ostrovnoy
# Processing Record 140 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+codrington
# City not found. Continue to next city.
# Processing Record 141 | sidi ali
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sidi ali
# City not found. Continue to next city.
# Processing Record 142 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+camacha
# Processing Record 143 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+okhotsk
# Processing Record 144 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+blagoyevo
# Processing Record 145 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ancud
# Processing Record 146 | mantua
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mantua
# Processing Record 147 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hilo
# Processing Record 148 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+broome
# Processing Record 149 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nikolskoye
# Processing Record 150 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+banda aceh
# Processing Record 151 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+alofi
# Processing Record 152 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+leh
# Processing Record 153 | berezanka
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+berezanka
# Processing Record 154 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kasongo-lunda
# Processing Record 155 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+najran
# Processing Record 156 | matamba
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+matamba
# Processing Record 157 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tasiilaq
# Processing Record 158 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+victoria
# Processing Record 159 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hofn
# City not found. Continue to next city.
# Processing Record 160 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+guerrero negro
# Processing Record 161 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+norman wells
# Processing Record 162 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+whitehorse
# Processing Record 163 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+khatanga
# Processing Record 164 | miri
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+miri
# Processing Record 165 | talas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+talas
# Processing Record 166 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+half moon bay
# Processing Record 167 | latung
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+latung
# Processing Record 168 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hamilton
# Processing Record 169 | manacapuru
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+manacapuru
# Processing Record 170 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+carnarvon
# Processing Record 171 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+antofagasta
# Processing Record 172 | yanam
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+yanam
# Processing Record 173 | fare
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+fare
# Processing Record 174 | ingham
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ingham
# Processing Record 175 | sayat
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sayat
# Processing Record 176 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pangnirtung
# Processing Record 177 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+jalu
# Processing Record 178 | laon
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+laon
# City not found. Continue to next city.
# Processing Record 179 | raasiku
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+raasiku
# Processing Record 180 | camden
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+camden
# Processing Record 181 | aberdeen
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+aberdeen
# Processing Record 182 | kuito
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kuito
# Processing Record 183 | koumra
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+koumra
# Processing Record 184 | opatija
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+opatija
# Processing Record 185 | kayes
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kayes
# Processing Record 186 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+flinders
# Processing Record 187 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+thompson
# Processing Record 188 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+itarema
# Processing Record 189 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+beloha
# City not found. Continue to next city.
# Processing Record 190 | pokosnoye
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pokosnoye
# Processing Record 191 | changji
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+changji
# City not found. Continue to next city.
# Processing Record 192 | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+goderich
# Processing Record 193 | oyonnax
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+oyonnax
# Processing Record 194 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ugoofaaru
# Processing Record 195 | clonakilty
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+clonakilty
# Processing Record 196 | vostok
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vostok
# Processing Record 197 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+portland
# Processing Record 198 | mokrousovo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mokrousovo
# Processing Record 199 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+moose factory
# City not found. Continue to next city.
# Processing Record 200 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saskylakh
# Processing Record 201 | palmares
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+palmares
# Processing Record 202 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nyurba
# Processing Record 203 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+longyearbyen
# Processing Record 204 | sabha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sabha
# Processing Record 205 | santona
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+santona
# Processing Record 206 | mezhdurechenskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mezhdurechenskiy
# Processing Record 207 | kourou
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kourou
# Processing Record 208 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+beringovskiy
# Processing Record 209 | moctezuma
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+moctezuma
# Processing Record 210 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+chuy
# Processing Record 211 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+chokurdakh
# Processing Record 212 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hobyo
# Processing Record 213 | manaus
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+manaus
# Processing Record 214 | maracacume
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+maracacume
# Processing Record 215 | deori khas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+deori khas
# Processing Record 216 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+constitucion
# Processing Record 217 | corn island
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+corn island
# City not found. Continue to next city.
# Processing Record 218 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+eydhafushi
# Processing Record 219 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+talnakh
# Processing Record 220 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+dikson
# Processing Record 221 | dalby
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+dalby
# Processing Record 222 | medowie
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+medowie
# Processing Record 223 | camalu
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+camalu
# Processing Record 224 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bilma
# Processing Record 225 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+isangel
# Processing Record 226 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port elizabeth
# Processing Record 227 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+souillac
# Processing Record 228 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+oktyabrskiy
# Processing Record 229 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+preobrazheniye
# Processing Record 230 | guamuchil
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+guamuchil
# Processing Record 231 | kitimat
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kitimat
# Processing Record 232 | bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bonthe
# Processing Record 233 | barcelos
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+barcelos
# Processing Record 234 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tazmalt
# Processing Record 235 | rockport
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+rockport
# Processing Record 236 | kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kirakira
# City not found. Continue to next city.
# Processing Record 237 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+husavik
# City not found. Continue to next city.
# Processing Record 238 | halifax
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+halifax
# Processing Record 239 | mortka
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mortka
# Processing Record 240 | destin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+destin
# Processing Record 241 | san jose
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san jose
# Processing Record 242 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hami
# Processing Record 243 | tabas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tabas
# Processing Record 244 | zahnitkiv
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+zahnitkiv
# Processing Record 245 | libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+libertador general san martin
# Processing Record 246 | tabou
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tabou
# Processing Record 247 | dali
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+dali
# Processing Record 248 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ulaangom
# City not found. Continue to next city.
# Processing Record 249 | taksimo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+taksimo
# City not found. Continue to next city.
# Processing Record 250 | ibra
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ibra
# Processing Record 251 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+richards bay
# Processing Record 252 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lasa
# Processing Record 253 | digby
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+digby
# Processing Record 254 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+srednekolymsk
# Processing Record 255 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sur
# Processing Record 256 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+novyy urengoy
# Processing Record 257 | linxia
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+linxia
# City not found. Continue to next city.
# Processing Record 258 | bhinga
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bhinga
# Processing Record 259 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hovd
# Processing Record 260 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+viedma
# Processing Record 261 | jinji
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+jinji
# Processing Record 262 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vila velha
# Processing Record 263 | amahai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+amahai
# Processing Record 264 | erzin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+erzin
# Processing Record 265 | ustron
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ustron
# Processing Record 266 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+narsaq
# Processing Record 267 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+hualmay
# Processing Record 268 | shaunavon
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+shaunavon
# Processing Record 269 | price
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+price
# Processing Record 270 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port alfred
# Processing Record 271 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tombouctou
# Processing Record 272 | porto nacional
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+porto nacional
# Processing Record 273 | charters towers
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+charters towers
# Processing Record 274 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+fort nelson
# Processing Record 275 | celestun
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+celestun
# Processing Record 276 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+aksu
# Processing Record 277 | brownwood
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+brownwood
# Processing Record 278 | wlodawa
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+wlodawa
# Processing Record 279 | port-de-bouc
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port-de-bouc
# Processing Record 280 | inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+inhambane
# Processing Record 281 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+clyde river
# Processing Record 282 | elizabeth city
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+elizabeth city
# Processing Record 283 | ewing
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ewing
# Processing Record 284 | namibe
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+namibe
# Processing Record 285 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+marsa matruh
# City not found. Continue to next city.
# Processing Record 286 | kongwa
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kongwa
# Processing Record 287 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+auki
# Processing Record 288 | severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+severobaykalsk
# Processing Record 289 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pisco
# Processing Record 290 | jatiroto
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+jatiroto
# Processing Record 291 | ca mau
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ca mau
# Processing Record 292 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lufilufi
# Processing Record 293 | aljezur
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+aljezur
# Processing Record 294 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ekhabi
# City not found. Continue to next city.
# Processing Record 295 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+rio gallegos
# Processing Record 296 | kilifarevo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kilifarevo
# Processing Record 297 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+caravelas
# Processing Record 298 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+naze
# Processing Record 299 | tyukhtet
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tyukhtet
# Processing Record 300 | wewak
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+wewak
# Processing Record 301 | brooks
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+brooks
# Processing Record 302 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+muros
# Processing Record 303 | the pas
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+the pas
# Processing Record 304 | abha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+abha
# City not found. Continue to next city.
# Processing Record 305 | san roque
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san roque
# Processing Record 306 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+pochutla
# Processing Record 307 | miranda
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+miranda
# Processing Record 308 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+salinopolis
# City not found. Continue to next city.
# Processing Record 309 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+cayenne
# Processing Record 310 | lingao
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lingao
# Processing Record 311 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+yerbogachen
# Processing Record 312 | gallup
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+gallup
# Processing Record 313 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+te anau
# Processing Record 314 | okahandja
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+okahandja
# Processing Record 315 | ferrol
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ferrol
# Processing Record 316 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+vila franca do campo
# Processing Record 317 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+egvekinot
# City not found. Continue to next city.
# Processing Record 318 | guymon
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+guymon
# Processing Record 319 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+juneau
# City not found. Continue to next city.
# Processing Record 320 | ati
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ati
# Processing Record 321 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+xai-xai
# Processing Record 322 | nurota
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nurota
# Processing Record 323 | tooele
# ...
# Processing Record 461 | forio
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+forio
# Processing Record 462 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san policarpo
# Processing Record 463 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+fairbanks
# Processing Record 464 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+chernyshevskiy
# Processing Record 465 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tocopilla
# City not found. Continue to next city.
# Processing Record 466 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sinnamary
# Processing Record 467 | san antonio
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san antonio
# Processing Record 468 | muromtsevo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+muromtsevo
# City not found. Continue to next city.
# Processing Record 469 | miles city
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+miles city
# Processing Record 470 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+broken hill
# Processing Record 471 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san ignacio
# Processing Record 472 | burnie
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+burnie
# City not found. Continue to next city.
# Processing Record 473 | bay saint louis
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bay saint louis
# City not found. Continue to next city.
# Processing Record 474 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kavaratti
# Processing Record 475 | boysun
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+boysun
# Processing Record 476 | ibotirama
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ibotirama
# Processing Record 477 | jambi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+jambi
# Processing Record 478 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+buraydah
# Processing Record 479 | serenje
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+serenje
# City not found. Continue to next city.
# Processing Record 480 | kattivakkam
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kattivakkam
# Processing Record 481 | makhachkala
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+makhachkala
# Processing Record 482 | carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+carutapera
# Processing Record 483 | elat
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+elat
# Processing Record 484 | praxedis guerrero
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+praxedis guerrero
# Processing Record 485 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bandarbeyla
# Processing Record 486 | majene
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+majene
# City not found. Continue to next city.
# Processing Record 487 | sumenep
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sumenep
# Processing Record 488 | algarrobo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+algarrobo
# Processing Record 489 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+faya
# Processing Record 490 | tanout
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tanout
# City not found. Continue to next city.
# Processing Record 491 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+samarai
# Processing Record 492 | atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+atbasar
# Processing Record 493 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ust-kuyga
# Processing Record 494 | yablochnyy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+yablochnyy
# Processing Record 495 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kulhudhuffushi
# Processing Record 496 | gouyave
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+gouyave
# Processing Record 497 | shirokiy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+shirokiy
# Processing Record 498 | ulvik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ulvik
# Processing Record 499 | algiers
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+algiers
# Processing Record 500 | boden
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+boden
# Processing Record 501 | kudymkar
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kudymkar
# Processing Record 502 | campo verde
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+campo verde
# Processing Record 503 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+anadyr
# Processing Record 504 | kyabe
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kyabe
# Processing Record 505 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+virginia beach
# Processing Record 506 | riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+riyadh
# Processing Record 507 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kalmunai
# Processing Record 508 | razdolinsk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+razdolinsk
# Processing Record 509 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+omboue
# Processing Record 510 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+honningsvag
# Processing Record 511 | kiunga
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kiunga
# Processing Record 512 | soyo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+soyo
# Processing Record 513 | smolenka
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+smolenka
# Processing Record 514 | suntar
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+suntar
# City not found. Continue to next city.
# Processing Record 515 | sheridan
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sheridan
# Processing Record 516 | kidero
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kidero
# City not found. Continue to next city.
# Processing Record 517 | aden
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+aden
# Processing Record 518 | okha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+okha
# Processing Record 519 | osmanabad
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+osmanabad
# Processing Record 520 | ranong
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ranong
# Processing Record 521 | oytal
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+oytal
# Processing Record 522 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+saint-louis
# Processing Record 523 | sandi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sandi
# Processing Record 524 | linkoping
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+linkoping
# Processing Record 525 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+ghanzi
# Processing Record 526 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+port hardy
# City not found. Continue to next city.
# Processing Record 527 | alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+alyangula
# Processing Record 528 | kara-tyube
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kara-tyube
# Processing Record 529 | bayji
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bayji
# Processing Record 530 | sao joao batista
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sao joao batista
# Processing Record 531 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+verkhoyansk
# City not found. Continue to next city.
# Processing Record 532 | mawlaik
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+mawlaik
# Processing Record 533 | sibu
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sibu
# Processing Record 534 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+grand gaube
# Processing Record 535 | kobayashi
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kobayashi
# Processing Record 536 | boende
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+boende
# Processing Record 537 | lakheri
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+lakheri
# Processing Record 538 | atyrau
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+atyrau
# Processing Record 539 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+karratha
# Processing Record 540 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bubaque
# Processing Record 541 | minas de barroteran
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+minas de barroteran
# Processing Record 542 | gambela
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+gambela
# Processing Record 543 | duluth
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+duluth
# City not found. Continue to next city.
# Processing Record 544 | doha
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+doha
# City not found. Continue to next city.
# Processing Record 545 | kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+kaeo
# Processing Record 546 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+abu zabad
# Processing Record 547 | guanhaes
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+guanhaes
# Processing Record 548 | sigli
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+sigli
# City not found. Continue to next city.
# Processing Record 549 | razgrad
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+razgrad
# City not found. Continue to next city.
# Processing Record 550 | baiyin
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+baiyin
# Processing Record 551 | shitanjing
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+shitanjing
# Processing Record 552 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+nouadhibou
# Processing Record 553 | san enrique
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+san enrique
# Processing Record 554 | tutoia
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tutoia
# Processing Record 555 | bodden town
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bodden town
# Processing Record 556 | matara
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+matara
# Processing Record 557 | rayong
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+rayong
# Processing Record 558 | bouna
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+bouna
# Processing Record 559 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+axim
# Processing Record 560 | tyler
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+tyler
# Processing Record 561 | beian
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+beian
# City not found. Continue to next city.
# Processing Record 562 | coroico
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+coroico
# Processing Record 563 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+meulaboh
# Processing Record 564 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+torbay
# Processing Record 565 | cody
# http://api.openweathermap.org/data/2.5/weather?appid=9ecea3f46b0249dfb8c170d02f47b360&units=metric&q=+cody
# City not found. Continue to next city.
# City not found. Continue to next city.
# City not found. Continue to next city.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)

no_cities = len(city_name)

print(f"The number of cities chosen for this study is {no_cities}")

weather_data.count()
# Out:
# The number of cities chosen for this study is 565
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv(output_data_file)

# Display weather_data frame head 

weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  Cape Town          20      ZA  1546639200        82 -33.93  18.42
# 1    Sorland          40      NO  1546636800       100  67.67  12.69
# 2     Kodiak           1      US  1546638900        52  39.95 -94.76
# 3       Lebu           0      ET  1546641026        76   8.96  38.73
# 4     Djenne           8      ML  1546642876        47  13.91  -4.55
#
#    Max Temp  Wind Speed
# 0     19.00        7.20
# 1      0.00        0.50
# 2     11.70        1.50
# 3      1.38        1.51
# 4     16.41        4.06

# %%
# to convert the date column from epoch format to date format
weather_data["Date"]=(pd.to_datetime(weather_data["Date"],unit='s')) 

# to remove anomolies where the humidity is above 100%
weather_data = weather_data[weather_data.Humidity <=100 ]
weather_data.sort_values('Humidity', ascending = False).head(5)
# Out:
#                City  Cloudiness Country                Date  Humidity    Lat  \
# 75        Upernavik          92      GL 2019-01-04 22:30:18       100  72.79
# 473       Kavaratti           0      IN 2019-01-04 23:02:58       100  10.57
# 95         Klaksvik          92      FO 2019-01-04 21:50:00       100  62.23
# 93   Severo-Kurilsk          68      RU 2019-01-04 22:29:42       100  50.68
# 193       Ugoofaaru          12      MV 2019-01-04 23:01:53       100   5.67
#
#         Lng  Max Temp  Wind Speed
# 75   -56.15    -10.27        4.36
# 473   72.64     27.81        2.56
# 95    -6.59      8.00        4.10
# 93   156.12     -6.26        2.86
# 193   73.00     27.73        7.11

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today = str(date.today())

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_v_MaxTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_v_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_v_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_v_Wind Speed.png")
plt.show()

# %% [markdown]
# Three Observable Trends:
#
# 1. Those cities with a negative latitude - have max temperatures that lie between 0 and 40 deg C.  Whilst those with a positive latitude have max temperatues that reduce the further north you travel.
# 2. The wind speeds tend to increase, the further away you are from the equator.
# 3. The equator (Latitude = 0), has little bearing on the Cloudiness and Humidity.
